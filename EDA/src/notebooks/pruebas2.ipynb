# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
import numpy as np

# %%
url = 'https://www.vgchartz.com/games/games.php?name=&keyword=&console=PS&region=All&developer=&publisher=&goty_year=&genre=Role-Playing&boxart=Both&banner=Both&ownership=Both&showmultiplat=No&results=50&order=TotalSales&showtotalsales=0&showtotalsales=1&showpublisher=0&showvgchartzscore=0&shownasales=0&shownasales=1&showdeveloper=0&showcriticscore=0&showpalsales=0&showpalsales=1&showreleasedate=0&showreleasedate=1&showuserscore=0&showjapansales=0&showjapansales=1&showlastupdate=0&showothersales=0&showothersales=1&showshipped=0'

# %%
lectura = pd.read_html('https://www.vgchartz.com/games/games.php?name=&keyword=&console=PS&region=All&developer=&publisher=&goty_year=&genre=Role-Playing&boxart=Both&banner=Both&ownership=Both&showmultiplat=No&results=50&order=TotalSales&showtotalsales=0&showtotalsales=1&showpublisher=0&showvgchartzscore=0&shownasales=0&shownasales=1&showdeveloper=0&showcriticscore=0&showpalsales=0&showpalsales=1&showreleasedate=0&showreleasedate=1&showuserscore=0&showjapansales=0&showjapansales=1&showlastupdate=0&showothersales=0&showothersales=1&showshipped=0')[-2]
lectura.columns = lectura.columns.get_level_values(2)

# %%
rpg=lectura[['Pos',"Game.1",'Total Sales','NA Sales','PAL Sales','Japan Sales','Other Sales','Release Date']] # me quedo con las columnas que me interesan
rpg.set_index('Pos',inplace=True)
nuevos_nombres = [
    'Nombre',
    'Ventas Totales',
    'Ventas Norte América',
    'Ventas Europa',
    'Ventas Japón',
    'Ventas Otros',
    'Fecha Salida'
]
rpg.columns = nuevos_nombres # Le aplico unos nombres que me interesan más 
# Para poder trabajar con los valores numericos quito las m
columnas_ventas = [
    'Ventas Totales',
    'Ventas Norte América',
    'Ventas Europa',
    'Ventas Japón',
    'Ventas Otros'
]
rpg[columnas_ventas] = rpg[columnas_ventas].apply(lambda x: x.str.replace('m', ''))
# Le damos formato numerico a las fechas
rpg['Fecha Salida'] = pd.to_datetime(rpg['Fecha Salida'])
rpg
# Out:
# C:\Users\eduar\AppData\Local\Temp\ipykernel_10980\2788637819.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rpg[columnas_ventas] = rpg[columnas_ventas].apply(lambda x: x.str.replace('m', ''))
# C:\Users\eduar\AppData\Local\Temp\ipykernel_10980\2788637819.py:23: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   rpg['Fecha Salida'] = pd.to_datetime(rpg['Fecha Salida'])
# C:\Users\eduar\AppData\Local\Temp\ipykernel_10980\2788637819.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#Leo la segunda página de la web y le aplico el mismo tratamiento
lectura2 = pd.read_html('https://www.vgchartz.com/games/games.php?page=2&console=PS&genre=Role-Playing&order=TotalSales&ownership=Both&direction=DESC&showtotalsales=1&shownasales=1&showpalsales=1&showjapansales=1&showothersales=1&showpublisher=0&showdeveloper=0&showreleasedate=1&showlastupdate=0&showvgchartzscore=0&showcriticscore=0&showuserscore=0&showshipped=0')[-2]
lectura2.columns = lectura2.columns.get_level_values(2)

# %%
rpg2=lectura2[['Pos',"Game.1",'Total Sales','NA Sales','PAL Sales','Japan Sales','Other Sales','Release Date']]
rpg2.set_index('Pos',inplace=True)
rpg2
nuevos_nombres = [
    'Nombre',
    'Ventas Totales',
    'Ventas Norte América',
    'Ventas Europa',
    'Ventas Japón',
    'Ventas Otros',
    'Fecha Salida'
]
rpg2.columns = nuevos_nombres
columnas_ventas = [
    'Ventas Totales',
    'Ventas Norte América',
    'Ventas Europa',
    'Ventas Japón',
    'Ventas Otros'
]
rpg2[columnas_ventas] = rpg2[columnas_ventas].apply(lambda x: x.str.replace('m', ''))
rpg2['Fecha Salida'] = pd.to_datetime(rpg2['Fecha Salida'])
rpg2
# Out:
# C:\Users\eduar\AppData\Local\Temp\ipykernel_10980\2144037874.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rpg2[columnas_ventas] = rpg2[columnas_ventas].apply(lambda x: x.str.replace('m', ''))
# C:\Users\eduar\AppData\Local\Temp\ipykernel_10980\2144037874.py:22: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   rpg2['Fecha Salida'] = pd.to_datetime(rpg2['Fecha Salida'])
# C:\Users\eduar\AppData\Local\Temp\ipykernel_10980\2144037874.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
fusionrpg = pd.concat([rpg, rpg2]) #junto ambos en un solo DF, ahora si en alguna fila tengo un Nan lo voy a desechar porque no me interesa
fusionrpg.dropna(axis=0,how="any",inplace=True)
fusionrpg = fusion.reset_index(drop=True)
fusionrpg
# Out:
#                                                Nombre Ventas Totales  \
# 0                                   Final Fantasy VII           9.72
# 1                                  Final Fantasy VIII           7.86
# 2                                    Final Fantasy IX           5.30
# 3                                    Dragon Quest VII           4.47
# 4                               Final Fantasy Tactics           2.45
# 5                                        Parasite Eve           2.10
# 6                               The Legend of Dragoon           1.86
# 7                                        Chrono Cross           1.86
# 8                                           Xenogears           1.46
# 9                                       SaGa Frontier           1.35
# 10                                      Digimon World           1.30
# 11                               Brave Fencer Musashi           1.14
# 12                                     Legend of Mana           1.11
# ...

# %%
# Out:
#                                               Nombre Ventas Totales  \
# 0                                  Final Fantasy VII           9.72
# 1                                 Final Fantasy VIII           7.86
# 2                                   Final Fantasy IX           5.30
# 3                                   Dragon Quest VII           4.47
# 4                              Final Fantasy Tactics           2.45
# 5                                       Parasite Eve           2.10
# 6                              The Legend of Dragoon           1.86
# 7                                       Chrono Cross           1.86
# 8                                          Xenogears           1.46
# 9                                      SaGa Frontier           1.35
# 10                                     Digimon World           1.30
# 11                              Brave Fencer Musashi           1.14
# 12                                    Legend of Mana           1.11
# ...

# %%
url = 'https://www.vgchartz.com/games/games.php?name=&keyword=&console=PS&region=All&developer=&publisher=&goty_year=&genre=Role-Playing&boxart=Both&banner=Both&ownership=Both&showmultiplat=No&results=50&order=TotalSales&showtotalsales=0&showtotalsales=1&showpublisher=0&showvgchartzscore=0&shownasales=0&shownasales=1&showdeveloper=0&showcriticscore=0&showpalsales=0&showpalsales=1&showreleasedate=0&showreleasedate=1&showuserscore=0&showjapansales=0&showjapansales=1&showlastupdate=0&showothersales=0&showothersales=1&showshipped=0'

# 1. pandas lee la URL y devuelve una lista con TODAS las tablas que encuentre
try:
    lista_de_dataframes = pd.read_html(url)

    # 2. Generalmente, la tabla que queremos es la primera. La seleccionamos.
    df = lista_de_dataframes[0]

    # 3. ¡Este es el paso clave!
    #    Si pandas creó un encabezado de varios niveles (MultiIndex),
    #    le decimos que queremos quedarnos solo con la fila inferior de nombres.
    #    El texto que me pasaste ("Unnamed: 10_level_0", etc.) sugiere que esto pasará.
    #    Usamos .get_level_values(1) para tomar la segunda fila de encabezados (índice 1).
    df.columns = df.columns.get_level_values(1)

    # 4. Verificamos cómo quedaron las columnas y las primeras filas
    print("Columnas finales:")
    print(df.columns)
    print("\nPrimeras 5 filas del DataFrame limpio:")
    print(df.head())

except ImportError:
    print("Error: Necesitas instalar 'lxml'. Ejecuta: pip install lxml")
except Exception as e:
    print(f"Ocurrió un error al leer la URL: {e}")
# Out:
# Ocurrió un error al leer la URL: Too many levels: Index has only 1 level, not 2

# %%
limpio

# %%
indices
# Out:
# []
